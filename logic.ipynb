# %% [markdown]
# 게임 로직
#
# 1. 준비
# - ai 오브젝트 생성
# - 크롬 환경(게임 페이지, 초점)
# - 각종 라이브러리 임포트
#
# 2. 게임 시작
# - 프레임스택 초기화
# - 메모리? 초기화
# - 시작 버튼 누름
#
# 3. 게임 루프
# - 프레임 캡쳐 및 스택 -> 합성곱 연산 -> q-value 산출
# - q-value에 의한 행동 혹은 epsilon의 랜덤 행동
# - 사망/생존 여부 판단
# - 결과에 따른 보상 누적
# - 결과 등을 메모리에 저장
# - 다음 프레임 시간까지 대기
# - 위의 행동을 사망시까지 반복
#
# 3. 게임 종료 후
# - 쌓인 학습데이터 정산 - 역전파?
# -
